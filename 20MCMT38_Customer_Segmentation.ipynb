# %% [markdown]
# # **To perform customer segmentation on banking data. It will help the banking marketing team to carry out targeted marketing campaigns tailored to specific groups.**

# %% [markdown]
# **Import Libraries and Data**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
df = pd.read_csv('/content/marketing_data.csv')

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  ...  PRC_FULL_PAYMENT  TENURE
# 0  C10001    40.900749  ...          0.000000      12
# 1  C10002  3202.467416  ...          0.222222      12
# 2  C10003  2495.148862  ...          0.000000      12
# 3  C10004  1666.670542  ...          0.000000      12
# 4  C10005   817.714335  ...          0.000000      12
#
# [5 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %% [markdown]
# **Average, minimum and maximum "BALANCE" amount.**

# %%
print('Average, min, max =', df['BALANCE'].mean(), df['BALANCE'].min(), df['BALANCE'].max())
# Out:
# Average, min, max = 1564.4748276781038 0.0 19043.13856

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY  ...  PRC_FULL_PAYMENT       TENURE
# count   8950.000000        8950.000000  ...       8950.000000  8950.000000
# mean    1564.474828           0.877271  ...          0.153715    11.517318
# std     2081.531879           0.236904  ...          0.292499     1.338331
# min        0.000000           0.000000  ...          0.000000     6.000000
# 25%      128.281915           0.888889  ...          0.000000    12.000000
# 50%      873.385231           1.000000  ...          0.000000    12.000000
# 75%     2054.140036           1.000000  ...          0.142857    12.000000
# max    19043.138560           1.000000  ...          1.000000    12.000000
#
# [8 rows x 17 columns]

# %% [markdown]
# *   **Customer who made the maximum "ONEOFF_PURCHASES".**
#
# *   **Customer who made the maximum cash advance transaction.**
#
# *   **Number of cash advance transactions made.**

# %%
df[df['ONEOFF_PURCHASES']  == df['ONEOFF_PURCHASES'].max()]
# Out:
#     CUST_ID      BALANCE  ...  PRC_FULL_PAYMENT  TENURE
# 550  C10574  11547.52001  ...              0.25      12
#
# [1 rows x 18 columns]

# %%
mx = df['CASH_ADVANCE'].max()

# %%
df[df['CASH_ADVANCE'] == mx]
# Out:
#      CUST_ID      BALANCE  ...  PRC_FULL_PAYMENT  TENURE
# 2159  C12226  10905.05381  ...               0.0      12
#
# [1 rows x 18 columns]

# %% [markdown]
# **Check the missing data.**

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
# Fill up the missing elements with mean of the 'MINIMUM_PAYMENT'
df.loc[(df['MINIMUM_PAYMENTS'].isnull() == True), 'MINIMUM_PAYMENTS'] = df['MINIMUM_PAYMENTS'].mean()

# %%
df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        1
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
# Fill up the missing elements with mean of the 'CREDIT_LIMIT'
df.loc[(df['CREDIT_LIMIT'].isnull() == True), 'CREDIT_LIMIT'] = df['CREDIT_LIMIT'].mean()

# %%
# Again check if there is a missing value.
df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %% [markdown]
# **Check the duplicated valuess in the data.**

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# CUST_ID column is not useful in segmentaion, hence remove it.
df.drop('CUST_ID', axis = 1, inplace = True)

# %%
df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  ...  PRC_FULL_PAYMENT  TENURE
# 0    40.900749           0.818182  ...          0.000000      12
# 1  3202.467416           0.909091  ...          0.222222      12
# 2  2495.148862           1.000000  ...          0.000000      12
# 3  1666.670542           0.636364  ...          0.000000      12
# 4   817.714335           1.000000  ...          0.000000      12
#
# [5 rows x 17 columns]

# %%
# check number of columns in datasets
n = len(df.columns)
n
# Out:
# 17

# %%
df.columns
# Out:
# Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
#        'TENURE'],
#       dtype='object')

# %%
# Draw the correlation matrix to check how the colums are correlated.
# Number closer to 1 means high correlation

correlations = df.corr()
f, ax = plt.subplots(figsize = (20,10))
sns.heatmap(correlations, annot = True)

# %% [markdown]
# # **K-Means Algorithm**
#
# *   K-Means is an unsupervised learning algorithm.
# *   K-Means group some data points together in a cluster in an unsupervised fashion.
# *   The algorithm groups points with similar attribute values together by calculating Euclidian distance between the points.

# %% [markdown]
# # **K-Means Algorithm Steps**
# 1. Choose number of clusters "K".
# 2. Select random K points that are going to be the centroids for each clusters.
# 3. Assign each data point to the nearest centroid, doing so will enable us to create "K" number of clusters.
# 4. Calculate a new centroid for each cluster.
# 5. Reassign each data point to the new closest centroid.
# 6. Go to step 4 and repeat.

# %% [markdown]
# # **Obtain optimal number of clusters using the elbow method.**

# %% [markdown]
# 1. The elbow method is a heuristic method of interpretation and validation of consistency within cluster analysis designed to help find the appropriate number of clusters in a dataset.
# 2. If the line chart looks like an arm, then the "elbow" on the arm is the value of k that is the best.

# %% [markdown]
# # **Scale the Data.**
# Feature scaling is essential for machine learning algorithms that calculate distances between data. If not scale, the feature with a higher value range starts dominating when calculating distances.

# %%
# Scale the data first
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)

# %%
df_scaled.shape
# Out:
# (8950, 17)

# %%
df_scaled
# Out:
# array([[-0.73198937, -0.24943448, -0.42489974, ..., -0.31096755,
#         -0.52555097,  0.36067954],
#        [ 0.78696085,  0.13432467, -0.46955188, ...,  0.08931021,
#          0.2342269 ,  0.36067954],
#        [ 0.44713513,  0.51808382, -0.10766823, ..., -0.10166318,
#         -0.52555097,  0.36067954],
#        ...,
#        [-0.7403981 , -0.18547673, -0.40196519, ..., -0.33546549,
#          0.32919999, -4.12276757],
#        [-0.74517423, -0.18547673, -0.46955188, ..., -0.34690648,
#          0.32919999, -4.12276757],
#        [-0.57257511, -0.88903307,  0.04214581, ..., -0.33294642,
#         -0.52555097, -4.12276757]])

# %%
scores_1 = []
range_values = range(1,20)

for i in range_values:
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(df_scaled)
    scores_1.append(kmeans.inertia_)
    
plt.plot(scores_1, 'bx-')
# From this we can observe that, 4th cluster seems to be forming the elbow of the curve. 
# However, the values does not reduce linearly until 8th cluster. 
# Let's choose the number of clusters to be 7 or 8.

# %% [markdown]
# Let's try with the first 7 columns of "df_scaled", then check the optimal number of clusters.

# %%
scores_1 = []
range_values = range(1,20)

for i in range_values:
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(df_scaled[:,:7])
    scores_1.append(kmeans.inertia_)
    
plt.plot(scores_1, 'bx-')

# %% [markdown]
# **Apply K-Mean algorithm with k value = 7 because we can see that 7 is the optimal number of clusters using elbow method.**

# %%
kmeans = KMeans(7)
kmeans.fit(df_scaled)
labels = kmeans.labels_ #label associate with each data point

# %%
kmeans.cluster_centers_.shape
# Out:
# (7, 17)

# %%
# centroid for each cluster
cluster_centers = pd.DataFrame(data = kmeans.cluster_centers_, columns = [df.columns])
cluster_centers
# Out:
#     BALANCE BALANCE_FREQUENCY  ... PRC_FULL_PAYMENT    TENURE
# 0  0.011118          0.402725  ...        -0.452428  0.272163
# 1  1.443484          0.415902  ...         0.814424  0.333671
# 2 -0.369672          0.332750  ...         0.298482  0.252845
# 3  1.674275          0.393268  ...        -0.390871  0.067512
# 4  0.136724          0.430033  ...         0.458805  0.307642
# 5 -0.335506         -0.348076  ...         0.012899 -3.193765
# 6 -0.701928         -2.130863  ...         0.296076  0.201184
#
# [7 rows x 17 columns]

# %%
cluster_centers = scaler.inverse_transform(cluster_centers)
cluster_centers = pd.DataFrame(data = cluster_centers, columns = [df.columns])
cluster_centers
# Out:
#        BALANCE BALANCE_FREQUENCY  ... PRC_FULL_PAYMENT     TENURE
# 0  1587.616735          0.972673  ...         0.021387  11.881542
# 1  4568.965194          0.975794  ...         0.391920  11.963855
# 2   795.034695          0.956096  ...         0.241015  11.855690
# 3  5049.336277          0.970432  ...         0.039391  11.607666
# 4  1849.053676          0.979142  ...         0.287907  11.929022
# 5   866.148306          0.794815  ...         0.157487   7.243243
# 6   103.470756          0.372489  ...         0.240312  11.786555
#
# [7 rows x 17 columns]

# %%
labels.shape # Labels associated to each data point
# Out:
# (8950,)

# %%
labels.max()
# Out:
# 6

# %%
labels.min()
# Out:
# 0

# %%
y_kmeans = kmeans.fit_predict(df_scaled)
y_kmeans
# Out:
# array([6, 1, 0, ..., 2, 2, 2], dtype=int32)

# %%
# concatenate the clusters labels to our original dataframe
creditcard_df_cluster = pd.concat([df, pd.DataFrame({'cluster':labels})], axis = 1)
creditcard_df_cluster.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ...  PRC_FULL_PAYMENT  TENURE  cluster
# 0    40.900749           0.818182      95.40  ...          0.000000      12        0
# 1  3202.467416           0.909091       0.00  ...          0.222222      12        3
# 2  2495.148862           1.000000     773.17  ...          0.000000      12        4
# 3  1666.670542           0.636364    1499.00  ...          0.000000      12        0
# 4   817.714335           1.000000      16.00  ...          0.000000      12        0
#
# [5 rows x 18 columns]

# %%
# Plot the histogram of various clusters
for i in df.columns:
  plt.figure(figsize = (35, 5))
  for j in range(7):
    plt.subplot(1,7,j+1)
    cluster = creditcard_df_cluster[creditcard_df_cluster['cluster'] == j]
    cluster[i].hist(bins = 20)
    plt.title('{}    \nCluster {} '.format(i,j))
  
  plt.show()

# %% [markdown]
# # **Apply principal component analysis**
# *   PCA is an unsupervised machine learning algorithm.
# *   PCA performs dimensionality reductions.
# *   PCA create new features called components.
# *   Components are composites of the uncorrelated given input features.

# %%
# TO obtain the principal components 
pca = PCA(n_components=2)
principal_comp = pca.fit_transform(df_scaled)
principal_comp
# Out:
# array([[-1.68222001, -1.07645855],
#        [-1.13829301,  2.50643978],
#        [ 0.96967952, -0.38348073],
#        ...,
#        [-0.92620299, -1.81078712],
#        [-2.33655077, -0.65796612],
#        [-0.55642356, -0.40044109]])

# %%
# Create a dataframe with the two components
pca_df = pd.DataFrame(data = principal_comp, columns =['pca1','pca2'])
pca_df.head()
# Out:
#        pca1      pca2
# 0 -1.682220 -1.076459
# 1 -1.138293  2.506440
# 2  0.969680 -0.383481
# 3 -0.873628  0.043151
# 4 -1.599433 -0.688584

# %%
# Concatenate the clusters labels to the dataframe
pca_df = pd.concat([pca_df,pd.DataFrame({'cluster':labels})], axis = 1)
pca_df.head()
# Out:
#        pca1      pca2  cluster
# 0 -1.682220 -1.076459        0
# 1 -1.138293  2.506440        3
# 2  0.969680 -0.383481        4
# 3 -0.873628  0.043151        0
# 4 -1.599433 -0.688584        0

# %%
# Plotting pca1 vs pca2
plt.figure(figsize=(10,10))
ax = sns.scatterplot(x="pca1", y="pca2", hue = "cluster", data = pca_df, palette =['red','green','blue','black','yellow','gray','pink'])
plt.show()

# %% [markdown]
# # **Repeat all the steps to get 4 clusters (K=4)**
#
# ---
#
#
# # Cluster 0 = First Customers cluster (Transactors)
# # Cluster 1 = Second customers cluster (revolvers)
# # Cluster 2 = Third customer cluster (VIP/Prime)
# # Cluster 3 = Fourth customer cluster (low tenure)

# %% [markdown]
# # **To perform customer segmentation on banking data. It will help the banking marketing team to carry out targeted marketing campaigns tailored to specific groups.**

# %% [markdown]
# **Import Libraries and Data**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
df = pd.read_csv('/content/marketing_data.csv')

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  ...  PRC_FULL_PAYMENT  TENURE
# 0  C10001    40.900749  ...          0.000000      12
# 1  C10002  3202.467416  ...          0.222222      12
# 2  C10003  2495.148862  ...          0.000000      12
# 3  C10004  1666.670542  ...          0.000000      12
# 4  C10005   817.714335  ...          0.000000      12
#
# [5 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %% [markdown]
# **Average, minimum and maximum "BALANCE" amount.**

# %%
print('Average, min, max =', df['BALANCE'].mean(), df['BALANCE'].min(), df['BALANCE'].max())
# Out:
# Average, min, max = 1564.4748276781038 0.0 19043.13856

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY  ...  PRC_FULL_PAYMENT       TENURE
# count   8950.000000        8950.000000  ...       8950.000000  8950.000000
# mean    1564.474828           0.877271  ...          0.153715    11.517318
# std     2081.531879           0.236904  ...          0.292499     1.338331
# min        0.000000           0.000000  ...          0.000000     6.000000
# 25%      128.281915           0.888889  ...          0.000000    12.000000
# 50%      873.385231           1.000000  ...          0.000000    12.000000
# 75%     2054.140036           1.000000  ...          0.142857    12.000000
# max    19043.138560           1.000000  ...          1.000000    12.000000
#
# [8 rows x 17 columns]

# %% [markdown]
# *   **Customer who made the maximum "ONEOFF_PURCHASES".**
#
# *   **Customer who made the maximum cash advance transaction.**
#
# *   **Number of cash advance transactions made.**

# %%
df[df['ONEOFF_PURCHASES']  == df['ONEOFF_PURCHASES'].max()]
# Out:
#     CUST_ID      BALANCE  ...  PRC_FULL_PAYMENT  TENURE
# 550  C10574  11547.52001  ...              0.25      12
#
# [1 rows x 18 columns]

# %%
mx = df['CASH_ADVANCE'].max()

# %%
df[df['CASH_ADVANCE'] == mx]
# Out:
#      CUST_ID      BALANCE  ...  PRC_FULL_PAYMENT  TENURE
# 2159  C12226  10905.05381  ...               0.0      12
#
# [1 rows x 18 columns]

# %% [markdown]
# **Check the missing data.**

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
# Fill up the missing elements with mean of the 'MINIMUM_PAYMENT'
df.loc[(df['MINIMUM_PAYMENTS'].isnull() == True), 'MINIMUM_PAYMENTS'] = df['MINIMUM_PAYMENTS'].mean()

# %%
df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        1
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
# Fill up the missing elements with mean of the 'CREDIT_LIMIT'
df.loc[(df['CREDIT_LIMIT'].isnull() == True), 'CREDIT_LIMIT'] = df['CREDIT_LIMIT'].mean()

# %%
# Again check if there is a missing value.
df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %% [markdown]
# **Check the duplicated valuess in the data.**

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# CUST_ID column is not useful in segmentaion, hence remove it.
df.drop('CUST_ID', axis = 1, inplace = True)

# %%
df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  ...  PRC_FULL_PAYMENT  TENURE
# 0    40.900749           0.818182  ...          0.000000      12
# 1  3202.467416           0.909091  ...          0.222222      12
# 2  2495.148862           1.000000  ...          0.000000      12
# 3  1666.670542           0.636364  ...          0.000000      12
# 4   817.714335           1.000000  ...          0.000000      12
#
# [5 rows x 17 columns]

# %%
# check number of columns in datasets
n = len(df.columns)
n
# Out:
# 17

# %%
df.columns
# Out:
# Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
#        'TENURE'],
#       dtype='object')

# %%
# Draw the correlation matrix to check how the colums are correlated.
# Number closer to 1 means high correlation

correlations = df.corr()
f, ax = plt.subplots(figsize = (20,10))
sns.heatmap(correlations, annot = True)

# %% [markdown]
# # **K-Means Algorithm**
#
# *   K-Means is an unsupervised learning algorithm.
# *   K-Means group some data points together in a cluster in an unsupervised fashion.
# *   The algorithm groups points with similar attribute values together by calculating Euclidian distance between the points.

# %% [markdown]
# # **K-Means Algorithm Steps**
# 1. Choose number of clusters "K".
# 2. Select random K points that are going to be the centroids for each clusters.
# 3. Assign each data point to the nearest centroid, doing so will enable us to create "K" number of clusters.
# 4. Calculate a new centroid for each cluster.
# 5. Reassign each data point to the new closest centroid.
# 6. Go to step 4 and repeat.

# %% [markdown]
# # **Obtain optimal number of clusters using the elbow method.**

# %% [markdown]
# 1. The elbow method is a heuristic method of interpretation and validation of consistency within cluster analysis designed to help find the appropriate number of clusters in a dataset.
# 2. If the line chart looks like an arm, then the "elbow" on the arm is the value of k that is the best.

# %% [markdown]
# # **Scale the Data.**
# Feature scaling is essential for machine learning algorithms that calculate distances between data. If not scale, the feature with a higher value range starts dominating when calculating distances.

# %%
# Scale the data first
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)

# %%
df_scaled.shape
# Out:
# (8950, 17)

# %%
df_scaled
# Out:
# array([[-0.73198937, -0.24943448, -0.42489974, ..., -0.31096755,
#         -0.52555097,  0.36067954],
#        [ 0.78696085,  0.13432467, -0.46955188, ...,  0.08931021,
#          0.2342269 ,  0.36067954],
#        [ 0.44713513,  0.51808382, -0.10766823, ..., -0.10166318,
#         -0.52555097,  0.36067954],
#        ...,
#        [-0.7403981 , -0.18547673, -0.40196519, ..., -0.33546549,
#          0.32919999, -4.12276757],
#        [-0.74517423, -0.18547673, -0.46955188, ..., -0.34690648,
#          0.32919999, -4.12276757],
#        [-0.57257511, -0.88903307,  0.04214581, ..., -0.33294642,
#         -0.52555097, -4.12276757]])

# %%
scores_1 = []
range_values = range(1,20)

for i in range_values:
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(df_scaled)
    scores_1.append(kmeans.inertia_)
    
plt.plot(scores_1, 'bx-')
# From this we can observe that, 4th cluster seems to be forming the elbow of the curve. 
# However, the values does not reduce linearly until 8th cluster.

# %% [markdown]
# Let's try with the first 7 columns of "df_scaled", then check the optimal number of clusters.

# %%
scores_1 = []
range_values = range(1,20)

for i in range_values:
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(df_scaled[:,:7])
    scores_1.append(kmeans.inertia_)
    
plt.plot(scores_1, 'bx-')

# %% [markdown]
# **Apply K-Mean algorithm with k value = 4.**

# %%
kmeans = KMeans(4)
kmeans.fit(df_scaled)
labels = kmeans.labels_ #label associate with each data point

# %%
kmeans.cluster_centers_.shape
# Out:
# (4, 17)

# %%
# centroid for each cluster
cluster_centers = pd.DataFrame(data = kmeans.cluster_centers_, columns = [df.columns])
cluster_centers
# Out:
#     BALANCE BALANCE_FREQUENCY  ... PRC_FULL_PAYMENT    TENURE
# 0  0.954485          0.462694  ...         0.454703  0.324140
# 1 -0.264919         -0.368276  ...        -0.258995 -0.052660
# 2  1.460497          0.384530  ...        -0.406168 -0.097912
# 3 -0.321755          0.242492  ...         0.395230  0.057654
#
# [4 rows x 17 columns]

# %%
cluster_centers = scaler.inverse_transform(cluster_centers)
cluster_centers = pd.DataFrame(data = cluster_centers, columns = [df.columns])
cluster_centers
# Out:
#        BALANCE BALANCE_FREQUENCY  ... PRC_FULL_PAYMENT     TENURE
# 0  3551.153761          0.986879  ...         0.286707  11.951100
# 1  1013.069082          0.790030  ...         0.077963  11.446846
# 2  4604.376032          0.968362  ...         0.034917  11.386288
# 3   894.768927          0.934715  ...         0.269313  11.594474
#
# [4 rows x 17 columns]

# %%
labels.shape # Labels associated to each data point
# Out:
# (8950,)

# %%
labels.max()
# Out:
# 3

# %%
labels.min()
# Out:
# 0

# %%
y_kmeans = kmeans.fit_predict(df_scaled)
y_kmeans
# Out:
# array([1, 3, 0, ..., 0, 1, 1], dtype=int32)

# %%
# concatenate the clusters labels to our original dataframe
creditcard_df_cluster = pd.concat([df, pd.DataFrame({'cluster':labels})], axis = 1)
creditcard_df_cluster.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ...  PRC_FULL_PAYMENT  TENURE  cluster
# 0    40.900749           0.818182      95.40  ...          0.000000      12        1
# 1  3202.467416           0.909091       0.00  ...          0.222222      12        2
# 2  2495.148862           1.000000     773.17  ...          0.000000      12        3
# 3  1666.670542           0.636364    1499.00  ...          0.000000      12        1
# 4   817.714335           1.000000      16.00  ...          0.000000      12        1
#
# [5 rows x 18 columns]

# %%
# Plot the histogram of various clusters
for i in df.columns:
  plt.figure(figsize = (35, 5))
  for j in range(4):
    plt.subplot(1,4,j+1)
    cluster = creditcard_df_cluster[creditcard_df_cluster['cluster'] == j]
    cluster[i].hist(bins = 20)
    plt.title('{}    \nCluster {} '.format(i,j))
  
  plt.show()

# %% [markdown]
# # **Apply principal component analysis**
# *   PCA is an unsupervised machine learning algorithm.
# *   PCA performs dimensionality reductions.
# *   PCA create new features called components.
# *   Components are composites of the uncorrelated given input features.

# %%
# TO obtain the principal components 
pca = PCA(n_components=2)
principal_comp = pca.fit_transform(df_scaled)
principal_comp
# Out:
# array([[-1.6822188 , -1.07644862],
#        [-1.13828738,  2.50648053],
#        [ 0.9696719 , -0.38353203],
#        ...,
#        [-0.92620315, -1.81078225],
#        [-2.33654416, -0.65795508],
#        [-0.5564197 , -0.40046459]])

# %%
# Create a dataframe with the two components
pca_df = pd.DataFrame(data = principal_comp, columns =['pca1','pca2'])
pca_df.head()
# Out:
#        pca1      pca2
# 0 -1.682219 -1.076449
# 1 -1.138287  2.506481
# 2  0.969672 -0.383532
# 3 -0.873633  0.043157
# 4 -1.599431 -0.688576

# %%
# Concatenate the clusters labels to the dataframe
pca_df = pd.concat([pca_df,pd.DataFrame({'cluster':labels})], axis = 1)
pca_df.head()
# Out:
#        pca1      pca2  cluster
# 0 -1.682219 -1.076449        1
# 1 -1.138287  2.506481        2
# 2  0.969672 -0.383532        3
# 3 -0.873633  0.043157        1
# 4 -1.599431 -0.688576        1

# %%
# Plotting pca1 vs pca2
plt.figure(figsize=(10,10))
ax = sns.scatterplot(x="pca1", y="pca2", hue = "cluster", data = pca_df, palette =['red','green','blue','black'])
plt.show()
